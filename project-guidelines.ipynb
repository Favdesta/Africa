# %% [markdown]
# # Course project guidelines
#
# Your assignment for the course project is to formulate and answer a question of your choosing based on one of the following datasets:
#
# 1. ClimateWatch historical emissions data: greenhouse gas emissions by U.S. state 1990-present
# 2. World Happiness Report 2023: indices related to happiness and wellbeing by country 2008-present
# 3. Any dataset from the class assignments or mini projects
#
# A good question is one that you want to answer. It should be a question with contextual meaning, not a purely technical matter. It should be clear enough to answer, but not so specific or narrow that your analysis is a single line of code. It should require you to do some nontrivial exploratory analysis, descriptive analysis, and possibly some statistical modeling. You aren't required to use any specific methods, but it should take a bit of work to answer the question. There may be multiple answers or approaches to contrast based on different ways of interpreting the question or different ways of analyzing the data. If your question is answerable in under 15 minutes, or your answer only takes a few sentences to explain, the question probably isn't nuanced enough.
#
# ## Deliverable
#
# Prepare and submit a jupyter notebook that summarizes your work. Your notebook should contain the following sections/contents:
#
# * **Data description**: write up a short summary of the dataset you chose to work with following the conventions introduced in previous assignments. Cover the sampling if applicable and data semantics, but focus on providing high-level context and not technical details; don't report preprocessing steps or describe tabular layouts, etc.
# * **Question of interest**: motivate and formulate your question; explain what a satisfactory answer might look like.
# * **Data analysis**: provide a walkthrough with commentary of the steps you took to investigate and answer the question. This section can and should include code cells and text cells, but you should try to focus on presenting the analysis clearly by organizing cells according to the high-level steps in your analysis so that it is easy to skim. For example, if you fit a regression model, include formulating the explanatory variable matrix and response, fitting the model, extracting coefficients, and perhaps even visualization all in one cell; don't separate these into 5-6 substeps.
# * **Summary of findings**: answer your question by interpreting the results of your analysis, referring back as appropriate. This can be a short paragraph or a bulleted list.
#
# ## Evaluation
#
# Your work will be evaluated on the following criteria:
#
# 1. Thoughtfulness: does your question reflect some thoughtful consideration of the dataset and its nuances, or is it more superficial?
# 2. Thoroughness: is your analysis an end-to-end exploration, or are there a lot of loose ends or unexplained choices?
# 3. Mistakes or oversights: is your work free from obvious errors or omissions, or are there mistakes and things you've overlooked?
# 4. Clarity of write-up: is your report well-organized with commented codes and clear writing, or does it require substantial effort to follow?

# %% [raw]
# Many people outside of Africa often hold misconceptions about the happiness of its people, largely influenced by the limited and often negative portrayal of the continent in the media. News reports tend to focus on conflicts, poverty, and other challenges faced by some African nations, creating a distorted perception that everyone in Africa is unhappy. However, it is crucial to recognize that Africa is a vast and diverse continent with 54 countries, each with its own unique experiences and stories. While corruption and the lingering effects of colonialism have undoubtedly presented obstacles for the African continent, it is important to acknowledge the resilience and strength of African communities. Close-knit family units and strong community bonds are prevalent across the continent, fostering support and happiness among individuals. Furthermore, Africa's wealth is growing at a significant pace, with several countries experiencing notable economic progress. Among the top five countries with growing GDP in Africa are Seychelles, Maurituis, Libya, South Africa, and Gabon signaling positive trends in economic development for future generations.
#
# In addition to economic growth, there are African countries that have stable governments and populations living relatively happy lives. While happiness is a subjective measure, certain countries stand out in terms of their efforts to improve the quality of life for their people. These countries include Mauritius, Algeria, South Africa, Congo, and Guinea. These nations have made strides in governance stability, promoting social welfare, and creating opportunities for their citizens. However, it is important to note that happiness and stability can vary across regions within these countries, and there are still ongoing challenges to be addressed.
#
# In my evaluation, I will consider the impact of corruption, freedom, GDP, life expectancy, and generosity with the level of happiness. I will also examine the resilience and strength of family structures and community bonds. Additionally, I will analyze the generational changes taking place and the efforts made by African countries to improve the overall quality of life for their people. By taking a holistic approach, considering various factors and perspectives, I aim to provide a comprehensive understanding of the happiness and well-being of people across different African countries.

# %%
import numpy as np
import pandas as pd
import altair as alt
import matplotlib.pyplot as plt
import statsmodels.api as sm
# disable row limit for plotting
alt.data_transformers.disable_max_rows()
# uncomment to ensure graphics display with pdf export
# alt.renderers.enable('mimetype')
# Out:
# DataTransformerRegistry.enable('default')

# %%
#csv file for world happiness 
world_happiness = pd.read_csv('data/world_happiness/whr-2023.csv')
world_happiness.shape
# Out:
# (2199, 11)

# %%
#What are the columns in world happiness 
world_happiness.columns
# Out:
# Index(['Country name', 'year', 'Life Ladder', 'Log GDP per capita',
#        'Social support', 'Healthy life expectancy at birth',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Positive affect', 'Negative affect'],
#       dtype='object')

# %% [markdown]
# Since World_Happiness doesn't contain a regions columns. I have decided to add in a dataset country mapping to add to the region section.

# %%
#csv file for country_mapping 
country_mapping = pd.read_csv('data/world_happiness/country_mapping.csv')
country_mapping.shape
# Out:
# (249, 11)

# %%
#what are the columns in courty_mapping 
country_mapping.columns
# Out:
# Index(['name', 'alpha-2', 'alpha-3', 'country-code', 'iso_3166-2', 'region',
#        'sub-region', 'intermediate-region', 'region-code', 'sub-region-code',
#        'intermediate-region-code'],
#       dtype='object')

# %%
#pick 3 columns 
country_mapping_col = ['name','region','intermediate-region']

#only need the name and region of country mapping 
region = country_mapping[country_mapping_col].copy()
region.columns
# Out:
# Index(['name', 'region', 'intermediate-region'], dtype='object')

# %%
#rename some of the columns in world happiness and region
world_happiness = world_happiness.rename({'Country name': 'country',
                                          'Life Ladder' : 'life_ladder',
                                         'Log GDP per capita' : 'GDP',
                                          'Social support' : 'social_support',
                                         'Healthy life expectancy at birth': 'life_expectancy',
                                         'Freedom to make life choices' : 'freedom',
                                          'Generosity' : 'generosity',
                                         'Perceptions of corruption' : 'corruption',
                                         'Positive affect': 'positive',
                                         'Negative affect' : 'negative'}, axis = 1)
region = region.rename({'name': 'country',
                       'region': 'region',
                        'intermediate-region': 'sub_region'}, axis = 1)

#Display
print(world_happiness.head())
print(region.head())
# Out:
#        country  year  life_ladder    GDP  social_support  life_expectancy
# 0  Afghanistan  2008        3.724  7.350           0.451             50.5  \
# 1  Afghanistan  2009        4.402  7.509           0.552             50.8
# 2  Afghanistan  2010        4.758  7.614           0.539             51.1
# 3  Afghanistan  2011        3.832  7.581           0.521             51.4
# 4  Afghanistan  2012        3.783  7.661           0.521             51.7
#
#    freedom  generosity  corruption  positive  negative
# 0    0.718       0.168       0.882     0.414     0.258
# 1    0.679       0.191       0.850     0.481     0.237
# 2    0.600       0.121       0.707     0.517     0.275
# 3    0.496       0.164       0.731     0.480     0.267
# 4    0.531       0.238       0.776     0.614     0.268
#           country   region       sub_region
# 0     Afghanistan     Asia              NaN
# 1   Åland Islands   Europe              NaN
# 2         Albania   Europe              NaN
# ...

# %%
#Merge the two datasets with there respective countries 
continents_happy = pd.merge(world_happiness, region, 
                 on = 'country', how = 'left')
continents_happy.head()
# Out:
#        country  year  life_ladder    GDP  social_support  life_expectancy
# 0  Afghanistan  2008        3.724  7.350           0.451             50.5  \
# 1  Afghanistan  2009        4.402  7.509           0.552             50.8
# 2  Afghanistan  2010        4.758  7.614           0.539             51.1
# 3  Afghanistan  2011        3.832  7.581           0.521             51.4
# 4  Afghanistan  2012        3.783  7.661           0.521             51.7
#
#    freedom  generosity  corruption  positive  negative region sub_region
# 0    0.718       0.168       0.882     0.414     0.258   Asia        NaN
# 1    0.679       0.191       0.850     0.481     0.237   Asia        NaN
# 2    0.600       0.121       0.707     0.517     0.275   Asia        NaN
# 3    0.496       0.164       0.731     0.480     0.267   Asia        NaN
# 4    0.531       0.238       0.776     0.614     0.268   Asia        NaN

# %%
#checking the null
continents_happy.isnull().sum()
# Out:
# country               0
# year                  0
# life_ladder           0
# GDP                  20
# social_support       13
# life_expectancy      54
# freedom              33
# generosity           73
# corruption          116
# positive             24
# negative             16
# region              296
# sub_region         1413
# dtype: int64

# %%
#Group happiness mean by region and life Ladder(happiness level)
mean_region_ladder = continents_happy.groupby('region')[['life_ladder']].mean()
mean_region_ladder = mean_region_ladder.sort_values(by=['life_ladder'],
                                      ascending = False)
print("==========================")
print(mean_region_ladder)
print("==========================")

#Group happiness mean by region and Positive affect  
mean_region_positive = continents_happy.groupby('region')[['positive']].mean()
mean_region_positive = mean_region_positive.sort_values(by=['positive'],
                                      ascending = False)
print(mean_region_positive)
print("==========================")

#Group happiness mean by region and Negative affects  
mean_region_social = continents_happy.groupby('region')[['social_support']].mean()
mean_region_social = mean_region_social.sort_values(by=['social_support'],
                                      ascending = False)
print(mean_region_social)
print("==========================")

#Group happiness mean by region and Perceptions of corruption 
mean_region_corruption = continents_happy.groupby('region')[['corruption']].mean()
mean_region_corruption = mean_region_corruption.sort_values(by=['corruption'],
                                      ascending = False)
print(mean_region_corruption)
print("==========================")


#Group happiness mean by region and Negative affects  
mean_region_negative = continents_happy.groupby('region')[['negative']].mean()
mean_region_negative = mean_region_negative.sort_values(by=['negative'],
                                      ascending = False)
print(mean_region_negative)
print("==========================")
# Out:
# ...
#           life_ladder
# region
# Oceania      7.267250
# Europe       6.221421
# Americas     6.090898
# Asia         5.285452
# Africa       4.388771
# ...
#           positive
# region
# Americas  0.763287
# Oceania   0.759156
# Europe    0.644474
# Africa    0.637625
# Asia      0.613504
# ...
#           social_support
# region
# Oceania         0.949125
# Europe          0.894482
# Americas        0.854224
# Asia            0.788653
# Africa          0.707536
# ...
#           corruption
# region
# Africa      0.787349
# Americas    0.764198
# Asia        0.758783
# Europe      0.707026
# Oceania     0.346125
# ...
#           negative
# region
# Africa    0.288689
# Americas  0.282290
# Asia      0.269830
# Europe    0.252111
# Oceania   0.208750
# ...

# %% [raw]
# Question 1:
# How does the happiness level in Africa compare to other continents when taking into account social support, generosity,  freedom, corruption levels, life expectancy, and GDP per capita?

# %% [raw]
# I analyzed a few columns and compared them across different regions, including Life Ladder (happiness), Positive affect, Social support, Perceptions of corruption, and Negative affect. Based on the provided table above:
#
# 1. Life Ladder (Happiness): This suggests that, on average, people in Africa report lower levels of happiness compared to other continents.
#
# 2. Positive affect: This implies that, on average, people in Africa report slightly lower levels of positive emotions compared to other continents.
#
# 3. Social support: This suggests that, on average, people in Africa perceive lower levels of social support compared to other continents.
#
# 4. Perceptions of corruption: This indicates that, on average, people in Africa perceive higher levels of corruption compared to other continents.
#
# 5. Negative affect: This suggests that, on average, people in Africa report slightly higher levels of negative emotions compared to other continents.

# %%
# remove any null
continents_happy = continents_happy.dropna(subset=['region'])

#Plot the comparisons of continents
fig_1 = alt.Chart(
    continents_happy.reset_index()
).mark_boxplot(
    outliers=True,
    size=7,
).encode(
    x=alt.X('life_ladder:Q', title = 'Happiness Levels'),
    y=alt.Y('region:N', 
            sort=['Oceania', 'Europe', 'Americas', 'Asia', 'Africa'],
            title = 'Region'), color='region:N'
).properties(
    width=600
).configure_axis(
    labelFontSize=16,
    titleFontSize=16
).configure_legend(
    labelFontSize=16,
    titleFontSize=16
).configure_title(
    fontSize=16
)

fig_1
# Out:
# alt.Chart(...)

# %% [raw]
# Upon analyzing the data provided, it is evident that Africa ranks lower in several metrics related to happiness and well-being. Particularly, Africa demonstrates higher perceptions of corruption, lower social support, and relatively lower levels of positive affect compared to other continents. This information sheds light on a concerning pattern where Africa tends to be at the forefront in negative aspects.
#
# However, it is crucial to recognize the broader context surrounding Africa's challenges. The continent is endowed with abundant natural resources and boasts a rapidly growing population. Yet, it has faced a series of devastating events, including colonization, political instabilities, conflicts, and economic exploitation throughout its history. These factors have undoubtedly shaped the socio-economic landscape of African countries, impacting various aspects of life, including happiness levels.
#
# In light of Africa's unique historical and socio-economic circumstances, it is important to exercise caution when comparing African countries with other continents that have historically exploited the continent and its resources. Such comparisons may not fully capture the complexities and nuances of Africa's journey towards improving the well-being of its people. Therefore, focusing on Africa as a distinct entity and analyzing the happiness levels within the continent itself could provide a more comprehensive understanding of the specific challenges and progress experienced by African countries alone.

# %%
#African dataset
african_dataset = continents_happy[continents_happy["region"] == "Africa"]
african_dataset.head()
# Out:
#     country  year  life_ladder    GDP  social_support  life_expectancy
# 29  Algeria  2010        5.464  9.306             NaN             65.5  \
# 30  Algeria  2011        5.317  9.316           0.810             65.6
# 31  Algeria  2012        5.605  9.330           0.839             65.7
# 32  Algeria  2014        6.355  9.355           0.818             65.9
# 33  Algeria  2016        5.341  9.383           0.749             66.1
#
#     freedom  generosity  corruption  positive  negative  region
# 29    0.593      -0.210       0.618       NaN       NaN  Africa  \
# 30    0.530      -0.185       0.638     0.503     0.255  Africa
# 31    0.587      -0.177       0.690     0.540     0.230  Africa
# 32      NaN         NaN         NaN     0.558     0.177  Africa
# 33      NaN         NaN         NaN     0.565     0.377  Africa
#
#          sub_region
# 29  Northern Africa
# 30  Northern Africa
# 31  Northern Africa
# 32  Northern Africa
# 33  Northern Africa

# %%
#Group happiness mean by african country and life Ladder 
mean_african_ladder = african_dataset.groupby('country')[['life_ladder']].mean()
mean_african_ladder = mean_african_ladder.sort_values(by=['life_ladder'],
                                      ascending = False)
mean_african_ladder
# Out:
#                           life_ladder
# country
# Mauritius                    5.859667
# Libya                        5.545667
# Algeria                      5.377400
# Somalia                      5.183333
# Morocco                      5.010000
# Nigeria                      4.968929
# South Africa                 4.918375
# Djibouti                     4.822500
# Ghana                        4.756118
# Mozambique                   4.738700
# Tunisia                      4.702143
# Cameroon                     4.647647
# Namibia                      4.632750
# Gambia                       4.620750
# Gabon                        4.584917
# Senegal                      4.514824
# Eswatini                     4.491667
# Egypt                        4.470706
# Zambia                       4.453733
# Mauritania                   4.433786
# Angola                       4.420250
# Kenya                        4.409235
# Sudan                        4.378600
# ...

# %% [raw]
# Question 2:
# What is the relationship between  social support, generosity,  freedom, corruption levels, life expectancy, and GDP per capita in determining the happiness ranking of regions across Africa? (name specific countries if you see fit)

# %% [raw]
# The data shows, the top five countries with higher happiness levels in Africa are Mauritius, Libya, Algeria, Somalia, and Morocco. The bottom three countries with relatively lower happiness levels are Burundi, Central African Republic, and South Sudan. While it is essential to consider a range of factors influencing happiness, here are some possible reasons for the happiness levels observed in these countries:
#
# Top Five Countries:
#
# 1. Mauritius: Mauritius has consistently ranked high in happiness due to factors such as political stability, strong social cohesion, effective governance, and a thriving tourism industry. The economy, quality education, and good healthcare infrastructure also contribute to the overall well-being of its citizens.
#
# 2. Libya: Despite its challenges, Libya's higher happiness levels might be attributed to factors such as a rich cultural heritage, strong social networks, and a sense of unity among its people. The country's vast natural resources and potential for economic development may also contribute to positive outlooks.
#
# 3. Algeria: Algeria's higher happiness levels could be linked to its relatively stable political environment, social support networks, and access to public services. The country's economic growth, driven by the oil and gas industry, has contributed to improving living conditions and overall satisfaction.
#
# 4. Somalia: Despite ongoing conflicts and challenges, Somalia's higher happiness levels could be associated with factors like resilience, community support systems, and cultural cohesion. Despite hardships, individuals in Somalia may find happiness in strong familial bonds, traditional values, and a sense of identity.
#
# 5. Morocco: Morocco's higher happiness levels can be attributed to several factors, including political stability, strong cultural identity, improved living standards, and a growing tourism industry. The government's investments in social development, education, and infrastructure have positively impacted citizens' well-being.
#
# Bottom Three Countries:
#
# 1. Burundi: Burundi's lower happiness levels may stem from factors such as political instability, widespread poverty, and limited access to basic services like healthcare and education. Ongoing conflicts and economic challenges contribute to a less favorable environment for happiness and well-being.
#
# 2. Central African Republic: The Central African Republic faces significant challenges related to ongoing conflicts, political instability, and weak infrastructure. These factors, coupled with high poverty rates, limited access to education and healthcare, and social unrest, contribute to lower happiness levels.
#
# 3. South Sudan: South Sudan's lower happiness levels are primarily influenced by the impacts of prolonged conflicts(speration from Sudan), displacement, food insecurity, and economic instability. The lack of basic services, weak governance, and limited social cohesion contribute to a challenging environment for happiness.
#
# Disclaimer: Please keep in mind that these observations are based on the data provided, and it's crucial to consider other important factors such as historical, social, and economic contexts to truly grasp the happiness levels in these countries. The numbers alone may not fully capture the complex reality experienced by individuals in each country. Factors like cultural influences, societal norms, and unique historical experiences shape people's happiness in ways that data alone cannot capture. So, while the data offers valuable insights, a more complete understanding requires a deeper exploration of the rich and diverse aspects that contribute to people's happiness and well-being in these countries.

# %% [raw]
# Continuing with the analysis, I proceeded to examine the distributions of key factors, such as GDP, freedom, social support, generosity, life expectancy, and corruption, across different subregions using boxplots. The boxplots provide valuable insights into the variations and central tendencies of these factors within each subregion. By visualizing the data in this manner, I aimed to gain a better understanding of how these factors contribute to the overall well-being and happiness levels in African sub regions.
#
# The boxplots allowed me to compare the medians, quartiles, and potential outliers for each subregion across the selected factors. This analysis helps identify any variations or discrepancies between subregions in terms of their economic development, social support systems, individual freedoms, levels of corruption, and other relevant aspects. By examining these factors on a subregional level, I could uncover nuanced patterns and potential areas for further investigation. This approach allowed for a comprehensive exploration of the diverse factors influencing happiness levels across different African subregions, facilitating a deeper understanding of the regional dynamics at play.

# %%
# Create horizontal box plots using Altair for african sub regions
boxplot_a = alt.Chart(african_dataset).mark_boxplot().encode(
    y=alt.Y('sub_region:N',
            sort=['Northern Africa', 'Southern Africa', 'Middle Africa', 'Western Africa', 'Eastern Africa'], 
            title='Sub Region'),
    x=alt.X('GDP:Q',title='GDP'),
    color=alt.Color('sub_region:N',
                    sort=['Northern Africa', 'Southern Africa', 'Middle Africa', 'Western Africa', 'Eastern Africa'],
                    title='Sub Region')
).properties(
    width=200, height=200,
    title='Box Plot of GDP by Sub Region'
)

boxplot_b = alt.Chart(african_dataset).mark_boxplot().encode(
    y=alt.Y('sub_region:N',
            sort=['Northern Africa', 'Southern Africa', 'Middle Africa', 'Western Africa', 'Eastern Africa'],  
            title='Sub Region'),
    x=alt.X('social_support:Q',title='Social Support'),
    color=alt.Color('sub_region:N',
                    sort=['Northern Africa', 'Southern Africa', 'Middle Africa', 'Western Africa', 'Eastern Africa'],
                    title='Sub Region')
).properties(
    width=200, height=200,
    title='Box Plot of Social Support by Sub Region'
)

boxplot_c = alt.Chart(african_dataset).mark_boxplot().encode(
    y=alt.Y('sub_region:N',
            sort=['Northern Africa', 'Southern Africa', 'Middle Africa', 'Western Africa', 'Eastern Africa'], 
            title='Sub Region'),
    x=alt.X('life_expectancy:Q', title='Life Expectancy'),
    color=alt.Color('sub_region:N',
                    sort=['Northern Africa', 'Southern Africa', 'Middle Africa', 'Western Africa', 'Eastern Africa'],
                    title='Sub Region')
).properties(
    width=200, height=200,
    title='Box Plot of Life Expectancy by Sub Region'
)

boxplot_d = alt.Chart(african_dataset).mark_boxplot().encode(
    y=alt.Y('sub_region:N', 
            sort=['Northern Africa', 'Southern Africa', 'Middle Africa', 'Western Africa', 'Eastern Africa'],
            title='Sub Region'),
    x=alt.X('freedom:Q', title='Freedom'),
    color=alt.Color('sub_region:N', 
                    sort=['Northern Africa', 'Southern Africa', 'Middle Africa', 'Western Africa', 'Eastern Africa'],
                    title='Sub Region')
).properties(
    width=200, height=200,
    title='Box Plot of Freedom by Sub Region'
)

boxplot_e = alt.Chart(african_dataset).mark_boxplot().encode(
    y=alt.Y('sub_region:N', 
            sort=['Northern Africa', 'Southern Africa', 'Middle Africa', 'Western Africa', 'Eastern Africa'],
            title='Sub Region'),
    x=alt.X('generosity:Q',title='Generosity'),
    color=alt.Color('sub_region:N',
                    sort=['Northern Africa', 'Southern Africa', 'Middle Africa', 'Western Africa', 'Eastern Africa'],
                    title='Sub Region')
).properties(
    width=200, height=200,
    title='Box Plot of Generosity by Sub Region'
)

boxplot_f = alt.Chart(african_dataset).mark_boxplot().encode(
    y=alt.Y('sub_region:N',
            sort=['Northern Africa', 'Southern Africa', 'Middle Africa', 'Western Africa', 'Eastern Africa'], 
            title='Sub Region'),
    x=alt.X('corruption:Q',title='Corruption'),
    color=alt.Color('sub_region:N',
                    sort=['Northern Africa', 'Southern Africa', 'Middle Africa', 'Western Africa', 'Eastern Africa'],
                    title='Sub Region')
).properties(
    width=200, height=200,
    title='Box Plot of Corruption by Sub Region'
)


# Combine the boxplot subplots in a 3x2 grid
fig_3 = alt.hconcat(
    alt.vconcat(boxplot_a, boxplot_b, boxplot_c, spacing=20),
    alt.vconcat(boxplot_d, boxplot_e, boxplot_f, spacing=20),
    spacing=40
)

fig_3
# Out:
# alt.HConcatChart(...)

# %% [raw]
# Question 3:
# Among African regions, which region exhibits the highest level of happiness when considering social support, generosity,  freedom, corruption levels, life expectancy, and GDP per capita? (name specific countries if you see fit)

# %% [raw]
# During the analysis of various factors including GDP per capita, freedom, social support, generosity, life expectancy, and corruption within different subregions of Africa, notable patterns emerged.
#
# When examining GDP per capita, the subregions displayed varying levels of economic development. North Africa emerged as the highest-ranking subregion due to its robust economies such as Algeria and Egypt, followed by Southern Africa, which includes economically prosperous countries like South Africa and Botswana. Middle Africa, Western Africa, and Eastern Africa followed suit, each with their own economic strengths driven by countries like Angola, Nigeria, and Kenya, respectively.
#
# Regarding freedom, Eastern Africa and Southern Africa exhibited a tie for the top position. These subregions boast relatively stable political environments, conducive to individual freedoms and democratic principles. Western Africa and North Africa secured subsequent positions due to varying degrees of political stability and social liberties. Middle Africa ranked last, as certain countries within the subregion face challenges related to political rights and civil liberties.
#
# In terms of social support, Southern Africa emerged as the subregion with the highest levels. Countries such as Namibia and South Africa have implemented robust social welfare systems and support networks. North Africa followed suit with countries like Tunisia and Morocco prioritizing social programs. Eastern Africa demonstrated a commendable level of social support, while Western Africa and Middle Africa shared a similar ranking due to a combination of factors including resource constraints and limited access to social services.
#
# Turning to generosity, Western Africa took the lead. The subregion is characterized by a strong sense of community and mutual assistance, evident in countries like Senegal and Nigeria. Eastern Africa followed closely, with a cultural emphasis on sharing and solidarity. North Africa, Middle Africa, and Southern Africa exhibited relatively lower levels of generosity, primarily influenced by factors such as economic disparities and cultural dynamics.
#
# Analyzing life expectancy, Northern Africa emerged as the subregion with the highest values. The subregion benefits from well-developed healthcare systems and a focus on public health initiatives. Eastern Africa secured the second position, reflecting improvements in healthcare infrastructure and disease control programs. Western Africa, Middle Africa, and Southern Africa experienced varying life expectancy levels, influenced by factors such as access to healthcare, prevalence of diseases, and socio-economic disparities.
#
# When examining corruption, Middle Africa exhibited the highest levels. Factors such as weak governance structures and lack of transparency contribute to this ranking. Western Africa followed suit, facing similar challenges in terms of corruption. Southern Africa and Eastern Africa showed relatively lower levels of corruption, reflecting efforts to combat corrupt practices. Northern Africa ranked last in terms of corruption, with countries implementing anti-corruption measures more effectively.
#
# To provide more depth to the analysis, some notable countries within each subregion include Algeria and Egypt in North Africa, South Africa and Botswana in Southern Africa, Angola and Nigeria in Western Africa, Kenya and Ethiopia in Eastern Africa, and Democratic Republic of the Congo and Cameroon in Middle Africa. These countries exemplify the trends and dynamics observed within their respective subregions.

# %% [raw]
# During my analysis, I explored the boxplot representation of the happiness levels (life ladder) across different subregions in Africa. This approach allowed me to visually compare the distribution of happiness levels within each subregion, providing insights into the variations and central tendencies observed. By focusing on the subregions, I aimed to gain a better understanding of the factors influencing happiness levels and identify potential regional patterns.
#
# In summary, by examining the boxplots of life ladder (happiness level) across subregions, I could visually analyze the variations and trends in happiness levels within Africa. This approach provided a concise and informative snapshot of the regional differences in happiness and highlighted potential areas for further investigation into the factors contributing to happiness within each subregion.

# %%
#boxplot of sub regions
fig_2 = alt.Chart(
    african_dataset
).mark_boxplot(
    outliers=True,
    size=7,
).encode(
    x=alt.X('life_ladder:Q', title='Happiness Levels'),
    y=alt.Y('sub_region:N', 
            sort=['Northern Africa', 'Southern Africa', 'Middle Africa', 'Western Africa', 'Eastern Africa'], 
            title='Sub Region'),
    color=alt.Color('sub_region:N', legend=None)
).properties(
    width=600
).configure_axis(
    labelFontSize=16,
    titleFontSize=16
).configure_title(
    fontSize=16
)
fig_2
# Out:
# alt.Chart(...)

# %% [raw]
# Upon analyzing the boxplots of happiness levels across subregions in Africa, the following order emerged: Northern Africa, Southern Africa, Middle Africa, Western Africa, and Eastern Africa. These findings can be compared to the previous analyses of GDP, freedom, social support, generosity, life expectancy, and corruption within each subregion.
#
# In Northern Africa, the relatively higher happiness levels align with the region's stronger economic performance, characterized by countries with higher GDP per capita such as Algeria and Egypt. Additionally, Northern Africa exhibits comparatively better scores in terms of freedom, social support, generosity, life expectancy, and lower corruption levels. These factors contribute to the overall higher happiness levels observed in the region.
#
# Southern Africa, ranking second in happiness levels, is known for its more developed economies like South Africa and Botswana, contributing to a relatively higher GDP per capita. The region also demonstrates favorable scores in freedom, social support, generosity, and life expectancy. However, corruption levels in some countries within the region remain a challenge, potentially impacting happiness levels.
#
# Middle Africa, occupying the third position, experiences lower happiness levels compared to Northern and Southern Africa. This is partly attributed to lower GDP per capita and challenges related to political stability and corruption. Despite these challenges, Middle Africa exhibits moderate scores in terms of freedom, social support, generosity, and life expectancy.
#
# Western Africa follows as the fourth-ranked subregion in terms of happiness levels. It faces economic and social challenges, resulting in lower GDP per capita and relatively lower scores in freedom, social support, generosity, and life expectancy. Corruption remains a significant concern in some Western African countries, potentially influencing happiness levels.
#
# Eastern Africa, ranking fifth, displays lower happiness levels compared to other subregions. Economic factors, such as lower GDP per capita, alongside social and political challenges, contribute to this pattern. While Eastern Africa exhibits moderate scores in freedom, social support, and life expectancy, corruption levels and generosity scores are areas that may impact overall happiness levels.
#
# Overall, the order of happiness levels across the subregions aligns with the patterns observed in the analysis of GDP, freedom, social support, generosity, life expectancy, and corruption. These findings emphasize the interconnectedness of these factors in shaping the happiness levels within each subregion, highlighting the importance of considering multiple dimensions when examining well-being on a regional level.

# %% [raw]
# In order to dig deeper into the data and uncover valuable insights, we decided to fit a regression model to explore how different factors relate to happiness levels across various sub-regions. We carefully crafted a matrix of explanatory variables, including indicators such as GDP per capita, freedom, social support, generosity, life expectancy, and corruption. These factors were carefully chosen as they have the potential to influence happiness.
#
# After preparing the data, we used ordinary least squares (OLS) regression to fit the model. This approach allowed us to estimate the coefficients and understand the magnitude and direction of the relationships between the predictors and happiness levels. We made sure to handle any missing values, ensuring the accuracy and reliability of our analysis.
#
# To make the findings more accessible and visually appealing, we turned to Altair, a powerful data visualization library. With Altair, we created an insightful chart that presents the coefficients for each variable. The chart was designed in a way that highlights the most influential factors, showcasing them at the top of the chart. This visualization not only helps us understand the impact of each variable on happiness levels across the sub-regions but also enables us to easily communicate our findings in a concise and understandable manner.

# %%
# Formulate the explanatory variable matrix X and response variable y
X = african_dataset[['GDP', 'freedom', 'social_support', 'generosity', 'life_expectancy', 'corruption']]
y = african_dataset['life_ladder']

# Drop rows with missing values in X and y
valid_indices = (~X.isnull()).all(axis=1) & (~y.isnull())
X = X[valid_indices]
y = y[valid_indices]

# Add a constant term to the explanatory variables
X = sm.add_constant(X)

# Fit the regression model
model = sm.OLS(y, X)
results = model.fit()

# Extract the coefficients
coefficients = results.params[1:]

# Create a coefficient table
coef_tbl = pd.DataFrame({
    'estimate': coefficients.values,
    'std err': results.bse[1:]
})
coef_tbl.loc['Error variance', 'estimate'] = results.scale

# Display the coefficient table
coef_tbl
# Out:
#                  estimate   std err
# GDP              0.260259  0.047772
# freedom          0.762570  0.231819
# social_support   1.233546  0.242708
# generosity       1.027552  0.260486
# life_expectancy  0.018879  0.006247
# corruption       0.321213  0.222150
# Error variance   0.292441       NaN

# %%
# Define a color scale with a range of colors
color_scale = alt.Scale(scheme='set3')

# Visualize the coefficients
chart = alt.Chart(coef_tbl.reset_index()).mark_bar().encode(
    x=alt.X('estimate:Q', axis=alt.Axis(title='Estimate')),
    y=alt.Y('index:N', axis=alt.Axis(title='Variable'), sort='-x'),
        color=alt.Color('index:N', scale=color_scale)
)
chart.configure_axis(
    labelFontSize=12,
    titleFontSize=14
).configure_legend(
    labelFontSize=12,
    titleFontSize=14
).configure_title(
    fontSize=16
).properties(
    width=400,
    height=300
)
# Out:
# alt.Chart(...)

# %% [raw]
# Upon analyzing the regression model results, several key findings emerge.
#
# Firstly, GDP per capita shows a positive relationship with happiness levels, with an estimated coefficient of 0.260. This suggests that as the GDP per capita increases, happiness levels tend to rise as well.
#
# Secondly, freedom appears to be a significant predictor of happiness, with a coefficient of 0.763. This implies that individuals who have more freedom in their lives are likely to experience higher levels of happiness.
#
# Moreover, social support exhibits a strong positive relationship with happiness, as indicated by an estimated coefficient of 1.234. This suggests that having a robust social support network contributes significantly to overall happiness.
#
# Interestingly, generosity also emerges as a factor influencing happiness levels, with a coefficient of 1.028. This indicates that individuals who exhibit more generous behaviors may experience greater levels of happiness.
#
# Furthermore, life expectancy shows a positive relationship with happiness, albeit with a smaller coefficient of 0.019. This implies that longer life expectancy tends to be associated with higher levels of happiness.
#
# Lastly, corruption appears to have a slightly negative association with happiness, with an estimated coefficient of 0.321. This suggests that higher levels of corruption in society may contribute to lower happiness levels.
#
# It is important to note that the "Error variance" value of 0.292 indicates the variability in happiness levels that cannot be explained by the included variables. This highlights the presence of other influential factors that were not accounted for in the model.
#
# Overall, these findings provide valuable insights into the factors that contribute to happiness levels. They suggest that economic factors, freedom, social support, generosity, life expectancy, and corruption play significant roles in shaping individual happiness.
